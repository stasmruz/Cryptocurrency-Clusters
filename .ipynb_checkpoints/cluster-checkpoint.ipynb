# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
#import csv file
crypto= pd.read_csv('crypto_data.csv')
crypto.head (-5)
# Out:
#      Unnamed: 0    CoinName    Algorithm  IsTrading ProofType  \
# 0            42     42 Coin       Scrypt       True   PoW/PoS
# 1           365     365Coin          X11       True   PoW/PoS
# 2           404     404Coin       Scrypt       True   PoW/PoS
# 3           611   SixEleven      SHA-256       True       PoW
# 4           808         808      SHA-256       True   PoW/PoS
# ...         ...         ...          ...        ...       ...
# 1242        GAP     Gapcoin       Scrypt       True   PoW/PoS
# 1243       SERO  Super Zero       Ethash       True       PoW
# 1244        UOS         UOS      SHA-256       True      DPoI
# 1245        BDX      Beldex  CryptoNight       True       PoW
# 1246        ZEN     Horizen     Equihash       True       PoW
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# ...

# %%
#find when istrading =true and drop Nas
crypto= crypto.loc[crypto['IsTrading']==True]

crypto=crypto.drop('IsTrading',axis=1)
crypto.head(-5)
# Out:
#      Unnamed: 0     CoinName Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin    Scrypt   PoW/PoS     4.199995e+01
# 1           365      365Coin       X11   PoW/PoS              NaN
# 2           404      404Coin    Scrypt   PoW/PoS     1.055185e+09
# 3           611    SixEleven   SHA-256       PoW              NaN
# 4           808          808   SHA-256   PoW/PoS     0.000000e+00
# ...         ...          ...       ...       ...              ...
# 1238       ZEPH       ZEPHYR   SHA-256      DPoS     2.000000e+09
# 1239        XQN     Quotient    Scrypt   PoW/PoS              NaN
# 1240       NETC  NetworkCoin       X13   PoW/PoS              NaN
# 1241       VPRC   VapersCoin    Scrypt       PoW              NaN
# 1242        GAP      Gapcoin    Scrypt   PoW/PoS     1.493105e+07
#
#      TotalCoinSupply
# 0                 42
# 1         2300000000
# 2          532000000
# 3             611000
# 4                  0
# ...              ...
# ...

# %%
crypto= crypto.dropna()
crypto.shape
# Out:
# (685, 6)

# %%
crypto=crypto[crypto['TotalCoinsMined']>0]
crypto.head(-5)
# Out:
#      Unnamed: 0    CoinName   Algorithm ProofType  TotalCoinsMined  \
# 0            42     42 Coin      Scrypt   PoW/PoS     4.199995e+01
# 2           404     404Coin      Scrypt   PoW/PoS     1.055185e+09
# 5          1337   EliteCoin         X13   PoW/PoS     2.927942e+10
# 7           BTC     Bitcoin     SHA-256       PoW     1.792718e+07
# 8           ETH    Ethereum      Ethash       PoW     1.076842e+08
# ...         ...         ...         ...       ...              ...
# 1226        TCH   TigerCash     SHA-256       PoS     1.000000e+09
# 1230      WAVES       Waves  Leased POS      LPoS     1.000000e+08
# 1231       PART     Particl         PoS       PoS     9.283138e+06
# 1234        BTT  BitTorrent       TRC10      DPoS     9.899887e+11
# 1237        NXT         Nxt         PoS  PoS/LPoS     1.000000e+09
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 5       314159265359
# 7           21000000
# 8                  0
# ...              ...
# ...

# %%
crypto = crypto.drop('Unnamed: 0', 1)
crypto.head(-5)
# Out:
#         CoinName   Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0        42 Coin      Scrypt   PoW/PoS     4.199995e+01              42
# 2        404Coin      Scrypt   PoW/PoS     1.055185e+09       532000000
# 5      EliteCoin         X13   PoW/PoS     2.927942e+10    314159265359
# 7        Bitcoin     SHA-256       PoW     1.792718e+07        21000000
# 8       Ethereum      Ethash       PoW     1.076842e+08               0
# ...          ...         ...       ...              ...             ...
# 1226   TigerCash     SHA-256       PoS     1.000000e+09      1000000000
# 1230       Waves  Leased POS      LPoS     1.000000e+08       100000000
# 1231     Particl         PoS       PoS     9.283138e+06         8634140
# 1234  BitTorrent       TRC10      DPoS     9.899887e+11    990000000000
# 1237         Nxt         PoS  PoS/LPoS     1.000000e+09      1000000000
#
# [527 rows x 5 columns]

# %%
# get dummies
crypto = crypto.drop('CoinName', axis=1)
x=pd.get_dummies(data=crypto, columns=['Algorithm','ProofType'])
x.head(-1)
# Out:
#       TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 0        4.199995e+01              42                                 0
# 2        1.055185e+09       532000000                                 0
# 5        2.927942e+10    314159265359                                 0
# 7        1.792718e+07        21000000                                 0
# 8        1.076842e+08               0                                 0
# ...               ...             ...                               ...
# 1237     1.000000e+09      1000000000                                 0
# 1238     2.000000e+09      2000000000                                 0
# 1242     1.493105e+07       250000000                                 0
# 1245     9.802226e+08      1400222610                                 0
# 1246     7.296538e+06        21000000                                 0
#
#       Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# ...

# %%
#set up scale use Pca
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
PC = PCA(n_components=.90)
p_c = PC.fit_transform(x_scaled)

# %%
#use TSNE test shape should reduce it
tsne_ = TSNE(perplexity=50)
tsne_ft = tsne_.fit_transform(p_c)
tsne_ft.shape
# Out:
# (532, 2)

# %%
# create a scatter plot to see if there are distant clusters
x = tsne_ft[:,0]
y = tsne_ft[:,1]

plt.scatter(x, y)
plt.show()

# %%
#create df for tsne for model
tsne_df = pd.DataFrame(data=tsne_ft)
#create a model to see how much clusters is best option
model = KMeans(n_clusters=5, random_state=5)
model.fit(tsne_df)
predictions = model.predict(tsne_df)
# plot 
plt.scatter(x=tsne_df[0], y=tsne_df[1],c=predictions)
plt.show()

# %%
#set up floop to deterimte intertia for each K,  then plot elbow plot 
I = []
k = list(range(1,10))

for a in k:
    kmeans = KMeans(n_clusters=a, random_state=0)
    kmeans.fit(p_c)
    I.append(kmeans.inertia_)

elbow = pd.DataFrame({'k': k, 'I': I})
elbow.plot.line(x='k', y='I')
plt.ylabel('Inertia')
plt.title('Elbow Plot')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %% [markdown]
# Although there is an outlier, I do beleive cryptocurrencies can be clustered together. The best fit that I have tested; 5 clusters shows best results.
